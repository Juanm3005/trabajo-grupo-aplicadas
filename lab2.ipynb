# %% [markdown]
# <a href="https://colab.research.google.com/github/Juanm3005/trabajo-grupo-aplicadas/blob/main/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicio 1
# ###Expresiones
# #### Ingresos: $I(x)=x(5.00-0.002x)$
# #### Utilidad: $U(x)=x(5-0.002(x)^2)-(3+1.10x)$
# #### Utilidad Simplificada: $U(x)=3.90x-0.002x^2-3$
#
# #### Primera Derivada
# Aplicamos primera devivada para hallar los puntos criticos
# #### $U'(x)=3.90-0.004x-3$
# Hallamos los puntos criticos
# #### $3.90-0.004x=0$
# #### $x=\frac{-3.90}{-0.004}$
#
# #### $x=975$
# Sacamos la segundo derivada para confirmar si es un punto maximo
# #### $U''(x)=-0.004$
# Como podemos comprobar el valor de la segunda derivada al ser negativa podemos decir que es un punto maximo
#
# #### Valor maximo
# #### $X=3.90(975)-0.004(975)^2-3$
# #### $X=1898.25$
#
# La producción maxima es de 975 para ganar la utilidad maxima de $1898.25
#
#
#
# Ejercicio 2
# Explicación del código
# def newton(fun, der, x_n, epsilon=1e-6, steps=50):  #  Define la función de Newton-Raphson con sus parámetros.
#     for n in range(steps + 1):                      #  Itera hasta un máximo de 'steps' veces.
#         f_x = fun(x_n)                              # Evalúa la función en el punto actual.
#         if abs(f_x) < epsilon:                      # Si el valor absoluto de la función es suficientemente pequeño...
#             return x_n                              # ... entonces se retorna x_n como la raíz encontrada.
#
#         d_f = der(x_n)                              # Evalúa la derivada en el punto actual.
#         if d_f == 0:                                # Si la derivada es cero
#             print('Error la derivada es cero')      # se muestra un error
#             return None                             # y se detiene el algoritmo.
#
#         x_n = x_n - f_x / d_f                       # Actualiza el valor de x_n usando la fórmula de Newton-Raphson.
#
#     return None                                     # Si no se encuentra una raíz en 'steps' iteraciones, retorna None.

# %%
#Ejercicio 3
#3.1
import numpy as np
import matplotlib.pyplot as plt

# Método de Newton-Raphson
def newton_raphson(f, fprime, x0, tol=1e-4, maxiter=50):
    x = x0
    for i in range(maxiter):
        fx = f(x)
        if abs(fx) < tol:
            return x
        fp = fprime(x)
        if fp == 0:
            print('Error: la derivada es cero')
            break
        x = x - fx / fp
    return x

# Funciones y derivadas
f1 = lambda x: x*5 - 6*x*3 + 2*x - 2
df1 = lambda x: 5*x*4 - 18*x*2 + 2

f2 = lambda x: np.sin(x) - x**2
df2 = lambda x: np.cos(x) - 2*x

f3 = lambda t: np.cos(t) - t**2
df3 = lambda t: -np.sin(t) - 2*t

f4 = lambda x: 2*np.sin(x) - np.sqrt(x + 1)
df4 = lambda x: 2*np.cos(x) - 1/(2*np.sqrt(x + 1))

# Graficar funciones
x_vals = np.linspace(-3, 3, 400)
functions = [(f1, "f1(x)"), (f2, "f2(x)"), (f3, "f3(t)"), (f4, "f4(x)")]

fig, axs = plt.subplots(2, 2, figsize=(12, 8))
axs = axs.flatten()
for i, (f, label) in enumerate(functions):
    axs[i].axhline(0, color='black', linewidth=0.5)
    axs[i].plot(x_vals, f(x_vals), label=label)
    axs[i].legend()
    axs[i].grid(True)
plt.tight_layout()
plt.show()

# Aproximaciones iniciales obtenidas del gráfico
initial_guesses = [0.5, 0.5, 0.8, 1.2]
functions_and_derivatives = [(f1, df1), (f2, df2), (f3, df3), (f4, df4)]

# Ejecutar Newton-Raphson
solutions = []
for (f, df), x0 in zip(functions_and_derivatives, initial_guesses):
    root = newton_raphson(f, df, x0, tol=1e-4)
    solutions.append(root)

# Mostrar resultados
for i, sol in enumerate(solutions, start=1):
    print(f"Solución {i}: {sol}")


#Ejercio 3.2
# Definimos la función y su derivada
def f(x):
    return x**3 - 2

def f_prime(x):
    return 3 * x**2

# Método de Newton-Raphson
def newton_raphson(f, fprime, x0, tol, maxiter):
    x = x0
    for i in range(maxiter):
        fx = f(x)
        if abs(fx) < tol:
            print(f"Iteraciones: {i}")
            return x  # Solución encontrada con tolerancia deseada

        fp = fprime(x)
        if fp == 0:
            print("Error: la derivada es cero")
            return None

        x = x - fx / fp  # Actualización de Newton

    print("No se alcanzó la tolerancia en el número máximo de iteraciones")
    return x

# Parámetros iniciales
x0 = 1.0          # Suposición inicial
tol = 0.00005     # Tolerancia deseada
maxiter = 100     # Máximo número de iteraciones

# Llamada al método de Newton-Raphson
resultado = newton_raphson(f, f_prime, x0, tol, maxiter)

# Imprimir resultado
if resultado is not None:
    print(f"Raíz cúbica aproximada de 2: {resultado}")
    print(f"Error absoluto: {abs(resultado**3 - 2)}")
# Out:
# <ipython-input-1-05153810c0bf>:30: RuntimeWarning: invalid value encountered in sqrt
#   f4 = lambda x: 2*np.sin(x) - np.sqrt(x + 1)
# Solución 1: -33.03600345037663
# Solución 2: 0.8767274201470954
# Solución 3: 0.8241323765632924
# Solución 4: 0.7135340075495848
# Iteraciones: 4
# Raíz cúbica aproximada de 2: 1.2599210500177698
# Error absoluto: 5.852585083232498e-10

# %% [markdown]
# ![5.jpg](data:image/jpeg;base64,...)![4.jpg](data:image/jpeg;base64,...)![3.jpg](data:image/jpeg;base64,...)![2.jpg](data:image/jpeg;base64,...)![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![6.jpg](data:image/jpeg;base64,...)![7.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #***ejercicios de graficas:***
#
# 1. $f(x) = \frac{x}{x+1}$
#
# # **Verificar dominio**
# $f(x) = \frac{x}{x+1}$
#
# $x+1 \neq 0$
#
# $x \neq -1$
#
# $Do(-∞, -1)(-1, ∞)$
#
# # **Verificar si es par o impar**
#
# $f(-x) = \frac{-x}{-x + 1}$
#
# $f(-x) = \frac{-x}{1 - x}$
#
# $\frac{x}{x+1} \neq \frac{-x}{1 - x}$
#
# **No es par**
#
#
# $-f(x) = -\left(\frac{x}{x+1}\right) = \frac{-x}{x+1}$
#
#
# $f(-x) = \frac{-x}{1 - x}$
#
#
# $\frac{-x}{x+1} \neq \frac{-x}{1 - x}$
#
# **No es impar**
#
# # **Cortes en los ejes**
#
# **Cortes en el eje Y**
#
# $f(0) = \frac{0}{0 + 1} = 0$
#
# corte con el eje $y$: $(0, 0)$
#
#
# **Cortes en el eje X**
#
# $\frac{x}{x + 1} = 0$
#
# $x = 0 (x + 1)$
#
# Corte con el eje $x$: $(0, 0)$
#
# # **Puntos criticos**
#
# **Derivada de $**f**(x) = \frac{x}{x+1}$**
#
# $f(x) = \frac{x}{x+1}$
#
# $f'(x) = \frac{(x+1)(1) - x(1)}{(x+1)^2}$
#
# $f'(x) = \frac{x+1 - x}{(x+1)^2}$
#
# $f'(x) = \frac{1}{(x+1)^2}$
#
# **Puntos críticos**
#
# $\frac{1}{(x+1)^2} = 0$
#
# la funcion no tiene ningun punto critico
#
# **Crecimiento o decrecimiento**
#
#
#
# Dominio de $f(x)$: $(-∞, -1)(-1, ∞)$
#
# $f(1) = \frac{(1)}{(1)+1}$
#
# $f(1) = 1$
#
# $f(-3) = \frac{(-3)}{(-3)+1}$
#
# $f(-3) = \frac{-3}{-2} = 1,5$
#
# la fucion crece en todo su dominio
#
# # **Asintotas**
#
# **Asíntota vertical**
#
# Denominador:
# $x + 1 = 0$
#
# $x = -1$
#
# **Asíntota vertical: $x = -1$**
#
# **Asíntota horizontal**
#
# los exponentes de las x son iguales por lo tanto se deben dividir los numeros que esten multiplicando la x en el numerador y denominador en este caso ambos son 1 por lo tanto la asintota horizontal es 1

# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = np.linspace(-5, -1.01, 70)
x2 = np.linspace(-0.99, 5, 70)


f = lambda x: x / (x + 1)


plt.plot(x1, f(x1), label=r"$f(x) = \frac{x}{x+1}$", color="blue")
plt.plot(x2, f(x2), color="blue")


plt.axvline(x=-1, color='red', linestyle='--', label='Asíntota vertical $x = -1$')
plt.axhline(y=1, color='green', linestyle='--', label='Asíntota horizontal $y = 1$')


plt.title("Gráfica de $f(x) = \\frac{x}{x+1}$")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.ylim(-10, 10)
plt.legend()
plt.show()

# %% [markdown]
# ## Ejercicios de gráficas
#
# ### Función:
#
# $$
# g(x) = \frac{|x| + x}{2} (3x + 2)
# $$
#
#
# ### **1. Verificar dominio**
#
#
#
# **Dominio:**
#
# $D_o = (-\infty, \infty)$
#
# ### **2. Verificar si es par o impar**
#
# $g(-x) = \frac{|-x| + (-x)}{2} (3(-x) + 2)$
#
# $g(-x) = \frac{|x| - x}{2} (-3x + 2)$
#
#  **no es par**
#
# $-g(x) = \frac{-(|x| + x)}{2} (3x + 2)$
#
#
# $\frac{|x| - x}{2} (-3x + 2) = \frac{-(|x| + x)}{2} (3x + 2)$
#
# $(|x| - x)(-3x + 2) = -(|x| + x)(3x + 2)$
#
# Izquierda
# $(|x| - x)(-3x + 2) = |x| \cdot (-3x + 2) - x \cdot (-3x + 2)= -3x|x| + 2|x| + 3x^2 - 2x $
#
# Derecha
#
# $-(|x| + x)(3x + 2) -( |x| \cdot 3x + |x| \cdot 2 + x \cdot 3x + x \cdot 2) = -3x|x| - 2|x| - 3x^2 - 2x$
#
# **comparamos**
#
# Izquierda $= -3x|x| + 2|x| + 3x^2 - 2x$
#
# Derecha $= -3x|x| - 2|x| - 3x^2 - 2x$
#
# **no es impar**
#
# # **3. Cortes en los ejes**
#
# **Intersección con eje y (x=0)**
#
# $g(0) = \frac{|0| + 0}{2} (3 \cdot 0 + 2) = \frac{0 + 0}{2} \cdot 2 = 0$
#
# **Intersección con eje x (g(x)=0)**
#
# $\frac{|x| + x}{2} = 0 \quad \text{o} \quad 3x + 2 = 0$
#
# **Caso 1: primer factor cero**
#
# $|x| + x = 0$
#
# Caso x >= 0
#
# $x \geq 0 $
#
# $x + x = 2x = 0$
#
# $x = 0$
#
# Caso x < 0
# $|x| = -x$
# $-x + x = 0$
#
# se cumple para todo $ x < 0$
#
# **Caso 2: segundo factor cero**
#
# $3x + 2 = 0$
#
# $x = -\frac{2}{3}$
#
# todos los x < 0 tienen corte en 0
#
# $g(x) = x(3x + 2) = 3x^2 + 2x$ (cuando x> 0)
#
# $x = 0$  (cuando x < 0.)
#
# **derivada cuando x > 0**
#
# $g'(x) = 6x + 2.$
#
# **derivada cuando x <= 0**
#
# $g'(x) = 0.$
#
# ---
#
# $6x + 2 = 0$
#
# $x = \frac {-2}{6}$
#
# todas las x menores o iguales a 0 son minimos locales y la funcion es continua en ese mismo rango y es creciente de 0 a infinito
#
# # **Asintotas**
#
# La asíntota horizontal se obtiene al calcular el límite cuando $x→±∞.$
#
# $g(x) = \lim_{x \to +\infty} (3x^2 + 2x) = +\infty$
#
# No hay asíntota horizontal a la derecha porque la función crece sin límite.
#
# Para $x→−∞:$
#
# $g(x) = \lim_{x \to -\infty} 0 = 0$
#
# Entonces, sí hay una asíntota horizontal por la izquierda, que es:
#
# $y = 0$

# %%
import numpy as np
import matplotlib.pyplot as plt


def g(x):
    return ((np.abs(x) + x) / 2) * (3 * x + 2)


x = np.linspace(-10, 10, 80)
y = g(x)

plt.figure(figsize=(8, 5))
plt.plot(x, y, label=r'$g(x) = \frac{|x| + x}{2}(3x + 2)$', color='blue')
plt.axhline(y=0, color='gray', linestyle='--', label='Asíntota horizontal: $y = 0$')
plt.axvline(x=0, color='black', linestyle=':', linewidth=1)
plt.title('Gráfica de $g(x)$')
plt.xlabel('x')
plt.ylabel('g(x)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Funcion
# $
# f(x)=\frac{x^2}{x^2-1}\\
# $
#
# ##**Dominio**
#
# $x^2-1 \neq 0$
#
# $x^2 \neq 1$
#
# $x \neq \sqrt1$
#
# dominio: R\-{1,-1}
#
#  Calculamos $f(-x)$:
#
# $f(-x) = \frac{(-x)^2}{(-x)^2 - 1}$
#
# $\frac{(-x)^2}{(-x)^2 - 1}= \frac{x^2}{x^2 - 1}$
#
# $f(-x) = f(x)$
#
# **la función es par**
#
# Verificación si la función es impar:
#
# Calculamos $-f(x)$:
#
# $-f(x) = -\frac{x^2}{x^2 - 1}$
#
# $f(-x) = \frac{x^2}{x^2 - 1} \neq -f(x)$
#
# **la función no es impar.**
#
#
# ## **Cortes en los ejes**
#
# **cortes en eje y:**
#
# $f(0) = \frac{0^2}{0^2 - 1} = 0$
#
# el corte en el eje $y$ es en el punto (0, 0)
#
# **Cortes en el eje X:**
#
# $\frac{x^2}{x^2 - 1} = 0$
#
# $x^2 = 0$
#
# $x = 0$
#
# Entonces, el único corte en el eje $x$ es en (0, 0)
#
# ##**puntos Criticos**
#
# $ f'(x) = -\frac{2x}{(x^2 - 1)^2}$
#
# $0 = -\frac{2x}{(x^2 - 1)^2}$
#
# $0 =2x$
#
# $ 0 = x$
#
# 0 en x es un punto critico en la cordenada (0,0)
#
# $f'(0.5) = -\frac{0.5\cdot 2}{(0.5^2 - 1)^2}$
#
# $f'(0.5) = 1,78$
#
# $f'(-0,5) = -\frac{-0.5\cdot 2}{(-0.5^2 - 1)^2}$
#
# $f'(-0,5) = -1,78$
#
# el punto 0,0 es un punto maximo
#
# ##**Concavidad**
#
# $f''(x) = \frac {6x^2 + 2}{(x^2 - 1)^{3}}$
#
# $f''(0) = \frac {6\cdot 0^2 + 2}{(0^2 - 1)^{3}}$
#
# $f''(0)= \frac{2}{-1}$
#
# de -1 a 1 es concava hacia abajo
#
# Asíntotas verticales en (x = 1) y (x = -1), ya que la función no está definida en estos puntos
#
# Asíntota horizontal: en (y = 1) ya que al ser una funcion racional y los exponentes de la x son iguales en el numerador y denominador se tienen que dividir los numeros que los multiplican y al ser estos 1 al dividirlos da 1

# %%
import numpy as np
import matplotlib.pyplot as plt


def f(x):
    return x**2 / (x**2 - 1)


x = np.linspace(-15, 15, 1000)



y = f(x)


x_crit = 0
y_crit = f(x_crit)

plt.figure(figsize=(10, 6))

plt.plot(x, y, label=r'$f(x) = \frac{x^2}{x^2 - 1}$', color='blue')


plt.axvline(x=1, color='red', linestyle='--', label='Asíntotas verticales')
plt.axvline(x=-1, color='red', linestyle='--')



plt.plot(x_crit, y_crit, 'go', label='Punto crítico (maximo local)')


plt.ylim(-5, 10)
plt.title('Gráfica de $f(x) = \\frac{x^2}{x^2 - 1}$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.show()

# %% [markdown]
# # **Ecuacion**
#
# $
# h(x) = \frac{5.235x^3 - 1.245}{7.126x - 3.141}
# $
#
# ## **Dominio**
#
# $
# 7.126x - 3.141 \neq 0
# $
#
# $
# 7.126x \neq 3.141
# $
#
# $
# x \neq \frac{3.141}{7.126} \approx 0.441
# $
#
# Por lo tanto, el dominio de \( h(x) \) es:
#
# $
# (-\infty, \frac{3.141}{7.126}) \cup (\frac{3.141}{7.126}, \infty)
# $
#
#
# ##**par o impar**
#
# Dada la función:
#
# $
# h(x) = \frac{5.235x^3 - 1.245}{7.126x - 3.141}
# $
#
# $
# h(-x) = \frac{5.235(-x)^3 - 1.245}{7.126(-x) - 3.141} = \frac{-5.235 x^3 - 1.245}{-7.126 x - 3.141}
# $
#
# $
# h(-x)= h(x)
# $
#
# No se cumple, porque:
#
# $
# h(-x) = \frac{-5.235 x^3 - 1.245}{-7.126 x - 3.141} \neq \frac{5.235 x^3 - 1.245}{7.126 x - 3.141}
# $
#
# **la función no es par.**
#
# $
# -h(x) = - \frac{5.235 x^3 - 1.245}{7.126 x - 3.141} = \frac{-(5.235 x^3 - 1.245)}{7.126 x - 3.141} = \frac{-5.235 x^3 + 1.245}{7.126 x - 3.141}
# $
#
# $
# h(-x) = \frac{-5.235 x^3 - 1.245}{-7.126 x - 3.141}
# $
#
# **la función no es impar**
#
# ##**cortes en los ejes**
#
# $
# 5.235x^3 - 1.245 = 0
# $
#
# $
# 5.235x^3 = 1.245
# $
#
# $
# x^3 = \frac{1.245}{5.235} \approx 0.238
# $
# $
# x \approx \sqrt[3]{0.238} \approx 0.620
# $
#
# Por lo tanto, la intersección con el eje (x) es aproximadamente en:
#
# $
# {x \approx 0.620}
# $
#
# **Corte en el eje y:**
#
# $
# h(0) = \frac{5.235(0)^3 - 1.245}{7.126(0) - 3.141} = \frac{-1.245}{-3.141} \approx 0.396
# $
#
# Entonces, la intersección con el eje (y) es en el punto:
#
# (0,0.396)
#
# ##**Puntos Criticos**
#
# $
# h(x) = \frac{5.235x^3 - 1.245}{7.126x - 3.141}
# $
#
# $
# h'(x) = \frac{(15.705x^2)(7.126x - 3.141) - (5.235x^3 - 1.245)(7.126)}{(7.126x - 3.141)^2}
# $
#
# $h'(x) = \frac{74.66862x^3 - 49.331205x^2 + 8.87097}{(7.126x - 3.141)^2}$
#
# $\frac{74.66862x^3 - 49.331205x^2 + 8.87097}{(7.126x - 3.141)^2} = 0$
#
# $74.66862x^3 - 49.331205x^2 + 8.87097 = 0$
#
# $74.66862x^3 - 49.331205x^2 = -8.87097$
#
# $x^2(74.66862x - 49.331205) = -8.87097$
#
# ##**

# %%
import sympy as sp
import numpy as np

# Define la variable y la función
x = sp.symbols('x')
# Ingresa tu función aquí
f = (5.235*x**3 - 1.245) / (7.126*x - 3.141)

# Derivadas simbólicas
f_prime_sym = sp.diff(f, x)
f_double_prime_sym = sp.diff(f_prime_sym, x)

# Convertir las funciones simbólicas a funciones numéricas
f_prime = sp.lambdify(x, f_prime_sym, 'numpy')
f_double_prime = sp.lambdify(x, f_double_prime_sym, 'numpy')
f_func = sp.lambdify(x, f, 'numpy')

# Tu función de Newton-Raphson
def newton_raphson(f, fprime, x0, tol, maxiter):
    x = x0
    for i in range(maxiter):
        fx = f(x)
        if abs(fx) < tol:
            print(f"Iteraciones: {i}")
            return x  # Solución encontrada con tolerancia deseada
        fp = fprime(x)
        if fp == 0:
            print("Error: la derivada es cero")
            return None
        x = x - fx / fp  # Actualización de Newton
    print("No se alcanzó la tolerancia en el número máximo de iteraciones")
    return x

# Punto inicial para buscar el punto crítico
x0 = -0.5  # Puedes cambiarlo según tus necesidades
tol = 1e-7
maxiter = 100

# Buscar el punto crítico
x_critico = newton_raphson(f_prime, f_double_prime, x0, tol, maxiter)

if x_critico is not None:
    # Determinar si es máximo o mínimo evaluando la segunda derivada
    concavidad = f_double_prime(x_critico)
    if concavidad > 0:
        tipo = 'mínimo'
    elif concavidad < 0:
        tipo = 'máximo'
    else:
        tipo = 'punto de inflexión'
    print(f"El punto crítico está en x ≈ {x_critico:.4f} y es un {tipo}.")
else:
    print("No se encontró un punto crítico.")
# Out:
# Iteraciones: 3
# El punto crítico está en x ≈ -0.3440 y es un mínimo.

# %% [markdown]
# al no poderse resolver matematicamente para hallar el punto critico tuve que usar el algoritmo matematico de newton raphson donde lo modifique para que dijera si es un punto maximo o minimo
#
# ##**asintota vertical**
#
# la asintota vertical es en el punto x = $\frac{3,141}{7,126} \approx 0.441$
#
# ##**asintota horizontal**
#
# no tiene asintota horizontal debido a que el exponente de la x del numerador es mañor que el de el denominador

# %%
import numpy as np
import matplotlib.pyplot as plt


def h(x):
    return (5.235 * x**3 - 1.245) / (7.126 * x - 3.141)


x = np.linspace(-5, 5, 1000)

discontinuidad = 3.141 / 7.126

x = x[np.abs(x - discontinuidad) > 0.01]


y = h(x)


plt.figure(figsize=(10, 6))
plt.plot(x, y, label=r'$h(x)=\frac{5.235x^3-1.245}{7.126x-3.141}$', color='blue')
plt.axvline(x=discontinuidad, color='red', linestyle='--', label=f'AsintotaVertical en x ≈ {discontinuidad:.3f}')
plt.title('Gráfica de la función h(x)')
plt.xlabel('x')
plt.ylabel('h(x)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # ***Ejercicio de graficas II***
#
# $f(x) = x^4 + x^2$
#
# f(x) es continua no tiene asintotas y su dominio abarca todos los reales
#
# $ f(-x) = (-x)^4 + (-x)^2 = x^4 + x^2 = f(x)$
#
# **es par**
#
# $f(0) = 0^4 + 0^2 = 0$
#
# $ f(1) = 1^4 + 1^2 = 1 + 1 = 2$
#
# $f'(x) = 4x^3 + 2$
#
# Para $( x > 0 ), ( f'(x) = 4x^3 + 2x > 0 )$, ya que la suma de dos términos positivos es positiva. Por lo tanto, ( f'(x) > 0 ) para ( x > 0 ), es decir, ( f ) es creciente en ese intervalo.
#
# $ f''(x) = 12x^2 + 2$
#
# Para $( x > 0 ), ( f''(x) = 12x^2 + 2 > 0 )$, ya que ambos términos son positivos. Por lo tanto, ( f''(x) > 0) para ( x > 0 ), lo que indica que la función es cóncava hacia arriba (convexa) en ese intervalo.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-20, 20, 400)


f = x**4 + x**2


f_prime = 4*x**3 + 2*x


f_double_prime = 12*x**2 + 2


plt.figure(figsize=(10, 6))


plt.plot(x, f, label=r'$f(x) = x^4 + x^2$', color='blue', linewidth=2)
plt.plot(x, f_prime, label=r"$f'(x) = 4x^3 + 2x$", color='green', linestyle='--')
plt.plot(x, f_double_prime, label=r"$f''(x) = 12x^2 + 2$", color='red', linestyle=':')


plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.title("Gráfica de $f(x)$, $f'(x)$ y $f''(x)$")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %% [markdown]
# # ***EJercicios Graficas III***
#
# $f(x) = a(x - 2)^3(x - 6)^2 + b$
#
#  La función está compuesta por polinomios y operaciones algebraicas elementales, por lo tanto, es continua en todo$ ({R}).$
#
# $  f(2) =a(0)^3(2 - 6)^2 + b = 0 + b = b$
